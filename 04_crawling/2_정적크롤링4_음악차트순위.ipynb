# %% [markdown]
# # 정적크롤링 실습. 음악순위

# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## 음악사이트 : 실시간 인기음악 Top100 추출

# %% [markdown]
# #### 음악순위 사이트 Bugs : https://music.bugs.co.kr/
#
# - 벅스차트 : https://music.bugs.co.kr/chart
#
# - 실시간 순위 정보는 \<table class='list trackList byChart'\> 태그에 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 순위별 곡 추출

# %% [markdown]
# #### 순위별 곡의 아티스트 추출

# %% [markdown]
# #### 순위별 곡과 아티스트를 데이터프레임에 저장

# %% [markdown]
# #### 실시간 순위를 위한 일자와 시간 정보를 파일이름으로하여 Top100 저장

# %% [markdown]
# ### 문제

# %% [markdown]
# #### 1. 일간 곡 순위 정보(곡명, 아티스트, 앨범명)를 추출하여 일자.csv로 저장하기

# %% [markdown]
# #### 2. 주간 곡 순위 정보(곡명, 아티스트, 앨범명)를 추출하여 csv로 저장하기

# %% [markdown]
# ------
