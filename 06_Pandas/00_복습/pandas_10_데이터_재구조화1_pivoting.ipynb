# %% [markdown]
# # pandas 데이터 재구조화(reshaping)

# %% [markdown]
# - 피버팅(pivoting)
# - 스태킹(stacking)과 언스태킹(unstacking)
# - 멜팅(melting)과 와이드투롱(wide_to_long)
# - 교차표(crosstab)

# %% [markdown]
# ## 1. 피벗팅(pivoting)

# %% [markdown]
# #### 예.
# - 데이터1 : 제품이 생산될 때 마다 코드, 크기, 생산 수량을 기록
#   ![image.png](attachment:005c0eb9-aaa6-452d-819b-8ad575edee76.png)

# %% [markdown]
# - 피벗테이블1 : 지역과 제품코드별 생산수량 요약
# ![image.png](attachment:5537f487-3727-483b-970d-d68f1184f63b.png)

# %% [markdown]
# - 피벗테이블2 :제품크기와 제품코드별로 생산수량 요약
# ![image.png](attachment:3971f0b0-e8c9-4081-b58b-82136c6ccf8d.png)

# %% [markdown]
# ### Pivoting
#
# - 쌓여있는(stacked/long) 데이터를 원하는 형태로 가공하여(record/wide) 재구조화된 형식으로 보여주는 것
# - stacked or long format -> record or wide format
#     - stacked format : 각 주제(subject)에 대해 여러 행이 존재하는 형식
# - 자료의 형태를 변경하기 위해 많이 사용하는 방법

# %% [markdown]
# ![image.png](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F255C7950585E784E01)
#
# - 출처 : https://rfriend.tistory.com/275

# %% [markdown]
# ### 피버팅을 위한 메소드 : **pivot(), pivot_table()**

# %% [markdown]
# ![image.png](https://pandas.pydata.org/docs/_images/reshaping_pivot.png)

# %% [markdown]
# ### pivot( )
# - pandas.pivot(data, index=None, columns=None, values=None)
# - DataFrame.pivot(index=None, columns=None, values=None)
# - https://pandas.pydata.org/docs/reference/api/pandas.pivot.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html

# %% [markdown]
# ### pivot_table( )

# %% [markdown]
# - 방법 : **두 개의 키를 사용**해서 데이터를 선택
#
#
#
# - **pivot_table(data, index=None, columns=None, values=None**,
#     aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)
#
#     - data : 분석할 데이터 프레임의 메서드 형식일 때는 필요하지 않음
#         - ex1. pandas.pivot_table(df1, )
#         - ex2. df1.pivot_table()
#     - index :  **행 인덱스**로 들어갈 키열 또는 키열의 리스트
#     - columns : **열 인덱스**로 들어갈 키열 또는 키열의 리스트
#     - values : 분석할 데이터 프레임에서 분석할 열
#     - fill_value : NaN이 표출될 때 대체값 지정
#     - margins : 모든 데이터를 분석한 결과를 행으로 표출할 지 여부
#     - margins_name : margins가 표출될 때 그 열(행)의 이름`

# %% [markdown]
# - **피벗테이블을 작성할 때 반드시 설정해야 되는 인수**
#     - data : 사용 데이터 프레임
#     - index : 행 인덱스로 사용할 필드(기준 필드로 작용됨)
#     - values : 인덱스 명을 제외한 나머지 값(data)은 수치 data 만 사용함
#     - aggfunc: 기본 함수가 평균(mean)함수 이기 때문에 각 데이터의 평균값이 반환

# %% [markdown]
# - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot_table.html

# %% [markdown]
# ### 예제1. pivot() 사용

# %% [markdown]
# ### 예제2. pivot() 사용

# %%
data = {"도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
        "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
        "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
        "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}

# %% [markdown]
# ### 예제3.

# %% [markdown]
# - 피벗테이블 : pivot()함수 이용시

# %% [markdown]
# - 피벗테이블1 : **pivot_table()** 함수 사용

# %% [markdown]
# - 피벗테이블2 : pivot_table( , **aggfunc='sum'**) 사용

# %% [markdown]
# - 피벗테이블3 : pivot_table( , **aggfunc=['sum','mean']**) 사용

# %% [markdown]
# - 피벗테이블4 : pivot_table( , **margins=True**) 사용

# %% [markdown]
# ### 예제4. 타이타닉 데이터 : pivot_table() 사용

# %% [markdown]
# - 피벗테이블1 : 선실등급별 숙박객의 성별 평균 나이

# %% [markdown]
# - 피벗테이블2 : 선실등급별 숙박객의 생존여부에 따른 평균 나이

# %% [markdown]
# - 피벗테이블3 : 선실등급과 성별에 대해 생존여부에 따른 나이와 티켓값의 평균과 최대값 계산

# %% [markdown]
# ----
