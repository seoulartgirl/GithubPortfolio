# %%
import numpy as np
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %% [markdown]
# ### 참고. 난수 생성 : np.random 모듈
#
# : https://docs.python.org/ko/3/library/random.html
#
# ##### np.random.seed(seed값)
#
# - seed : 난수 알고리즘에서 사용하는 기본 값
#     - seed 값이 같으면 동일한 난수 발생
#     - 예. np.random.seed(10)
#
#
# - 계속 변경되는 난수를 생성하려면 시드값이 매번 변하도록 지정
#     - 예. np.random.seed(int(time.time()))
#
#
# #### 난수 생성 함수
#
# - random.rand() : 주어진 형태의 난수 배열 생성
# - random.randint(최소값, 최대값, size=n)
#     - [최소값, 최대값)의 범위에서 임의의 정수 생성
#
# - random.randn() : 표준정규분포(Standard normal distribution)로부터 샘플링된 난수 생성
#
# - random.standard_normal() : 표준정규분포 난수 발생
#
# - random.normal([loc, scale, size]) : 정규분포 난수 생성
#
# - random.random_sample(size) : [0,1)사이의 난수 생성
#
# - random.choice(a[, size, replace, p]) : 주어진 배열로 부터 표본추출

# %%
# 고정 시드 값

np.random.seed(20)
np.random.randint(5, size=(4))
# Out:
# array([3, 2, 4, 2])

# %%
np.random.randint(5, size=(4))
# Out:
# array([1, 4, 3, 2])

# %%
np.random.randint(10,20, size=(4))
# Out:
# array([10, 16, 18, 15])

# %%
#변경 시드 값
import time

time.time()
# Out:
# 1712036680.509949

# %%
np.random.seed(int(time.time()))

# %% [markdown]
# ### 참고. 파이썬의 random 모듈
#
# #### 정수 난수 발생 함수
#
# ##### random.randrange(start, stop[, step])
# - range(start, stop, step)에서 임의로 선택된 요소를 반환
# - choice(range(start, stop, step))와 동등하지만 실제로 range 객체를 만들지는 않음
#
# ##### random.randint(a, b)
# - `a <= N <= b` 를 만족하는 임의의 정수 N을 반환
# - randrange(a, b+1)의 별칭
#
# #### 시퀀스 난수 발생 함수
# ##### random.choice(seq)
# - 비어 있지 않은 시퀀스 seq에서 임의의 요소를 반환
# - seq가 비어 있으면, IndexError를 발생
#
#
# ##### random.choices(population, weights=None, *, cum_weights=None, k=1)
# - population에서 중복을 허락하면서(with replacement) 선택한 k 크기의 요소 리스트를 반환
# - population이 비어 있으면 IndexError 발생
# - weights 시퀀스가 지정되면 상대 가중치에 따라 선택됨
# - weights나 cum_weights를 지정하지 않으면 같은 확률로 선택
# - weights 시퀀스가 제공되면, population 시퀀스와 길이가 같아야 함
# - weights와 cum_weights를 모두 지정하는 것은 TypeError
#
# ##### random.sample(population, k, *, counts=None)
# - population 시퀀스로부터 추출한 k개 길이의 새 리스트를 반환
# - random sampling without replacement
#
# #### 실수 난수 발생 함수
# ##### random.random()
# - `0.0 <= X < 1.0` 사이의 실수 반환
#
# ##### random.uniform(a, b)
# - `a <= b` 일 때 `a <= N <= b`, `b < a` 일 때 `b <= N <= a`를 만족하는 임의의 부동 소수점 숫자 N을 반환
# - 종단 값 b는 방정식 a + (b-a) * random()의 부동 소수점 자리 올림에 따라 범위에 포함되거나 포함되지 않을 수 있음

# %% [markdown]
# ----

# %% [markdown]
# # pandas 다중 인덱스(multi index)

# %% [markdown]
# - 행이나 열 인덱스가 계층으로 구성된 인덱스(Hierarchical indexing)

# %%
df = pd.DataFrame([[1,2,3,4],[2,3,4,6]],
                 index=['a b'.split()])
df
# Out:
#    0  1  2  3
# a  1  2  3  4
# b  2  3  4  6

# %%
df.index
# Out:
# MultiIndex([('a',),
#             ('b',)],
#            )

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# [학습 내용]
#
# 1. 다중 인덱스를 갖는 Series
# 2. 다중 인덱스를 갖는 DataFrame
# 3. MultiIndex 객체
# 4. 다중인덱스의 특정 레벨 제거 : droplevel()
# 5. 행인덱스 레벨 해제 : unstack()
# 6. 열인덱스 레벨 해제 : stack()
# 7. 다중인덱스의 레벨 교환 : swaplevel()
# 8. 다중인덱스의 행/열 추가
# 9. 다중인덱스 정렬

# %% [markdown]
# ### 1. 다중인덱스를 갖는 Series

# %% [markdown]
# #### 예1. 난수 데이터를 갖는 Series

# %%
arrays = [np.array(["bar", "bar", "baz", "baz",
                    "foo", "foo", "qux", "qux"]),
          np.array(["one", "two", "one", "two",
                    "one", "two", "one", "two"])]
type(arrays)
type(arrays[0])
np.random.seed(0)
s1 = pd.Series(np.random.randn(8), index=arrays)
s1
# Out:
# list
# numpy.ndarray
# bar  one    1.764052
#      two    0.400157
# baz  one    0.978738
#      two    2.240893
# foo  one    1.867558
#      two   -0.977278
# qux  one    0.950088
#      two   -0.151357
# dtype: float64

# %% [markdown]
# #### 예2. 키를 튜플로 갖는 딕셔너리의 데이터로 Series 생성

# %%
# 키를 튜플로 갖는 딕셔너리 데이터
data= {('James', 'Eng'): 100,
        ('James', 'Math') : 90,
        ('Ted', 'Eng') : 90,
        ('Ted', 'Math') : 70,
        ('Adam', 'Eng') : 85,
        ('Adam', 'Math') : 90 }
data
# Out:
# {('James', 'Eng'): 100,
#  ('James', 'Math'): 90,
#  ('Ted', 'Eng'): 90,
#  ('Ted', 'Math'): 70,
#  ('Adam', 'Eng'): 85,
#  ('Adam', 'Math'): 90}

# %%
data_list = [{'name': key[0], 'course': key[1], 'score': value} for key, value in data.items()]
s2 = pd.DataFrame(data_list)
s2
# Out:
#     name course  score
# 0  James    Eng    100
# 1  James   Math     90
# 2    Ted    Eng     90
# 3    Ted   Math     70
# 4   Adam    Eng     85
# 5   Adam   Math     90

# %%
s2 = pd.DataFrame(data.values(), 
                  index=pd.MultiIndex.from_tuples(data.keys(), 
                names=['name', 'course']), columns=['score'])
s2
# Out:
#               score
# name  course
# James Eng       100
#       Math       90
# Ted   Eng        90
#       Math       70
# Adam  Eng        85
#       Math       90

# %%
s2.index
# Out:
# MultiIndex([('James',  'Eng'),
#             ('James', 'Math'),
#             (  'Ted',  'Eng'),
#             (  'Ted', 'Math'),
#             ( 'Adam',  'Eng'),
#             ( 'Adam', 'Math')],
#            names=['name', 'course'])

# %% [markdown]
# #### 인덱스의 이름 지정 : 시리즈.index.names = [ , ]

# %%
s2.index.names=['name', 'course']

# %% [markdown]
# #### 다중인덱스를 갖는 Series의 인덱싱
#
# - 시리즈[상위인덱스]
# - 시리즈.상위인덱스
# - 시리즈[(상위인덱스, 하위인덱스)]
# - 시리즈.상위인데스,하위인덱스
# - 시리즈[:, 하위인덱스]

# %%
s2.loc['James']
# Out:
#         score
# course
# Eng       100
# Math       90

# %%
s2.loc['Ted']
# Out:
#         score
# course
# Eng        90
# Math       70

# %%
s2.Ted
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d8/9nns59h14_z0hzcqldblr_v00000gn/T/ipykernel_2714/353737609.py in ?()
# ----> 1 s2.Ted
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Ted'

# %%
s2['James', 'Ted']

# %%
s2[('James', 'Eng')]

# %%
s2.Ted.Eng

# %%
s2[:, 'Eng']

# %%
s2['James', :]
#s2['James']

# %% [markdown]
# ### 2. 다중 인덱스를 갖는 DataFrame

# %% [markdown]
# - 데이터 프레임 생성 시 생성자에서 columns인수나 index 인수를  2차원 리스트(행렬) 형태로 지정할 경우

# %% [markdown]
# #### 1) column인덱스를 다중 인덱스로 갖는 DataFrame

# %%
np.random.seed(10)
data = np.round(np.random.randn(5,4), 2) #round 로 소숫점 아래 둘째 자리로 자름
data

# %%
df = pd.DataFrame(data=data, 
                  columns = [['A','A','B','B'],['C1','C2','C3','C4']])
df
# Out:
# Empty DataFrame
# Columns: [(A, C1), (A, C2), (B, C3), (B, C4)]
# Index: []

# %%
df.columns
# Out:
# MultiIndex([('A', 'C1'),
#             ('A', 'C2'),
#             ('B', 'C3'),
#             ('B', 'C4')],
#            )

# %% [markdown]
# #### 열 인덱싱(1): df[상위인덱스]
# - 상위 인덱스의 모든 열에 대한 데이터프레임 반환

# %%
df[('A')]
# Out:
# Empty DataFrame
# Columns: [C1, C2]
# Index: []

# %% [markdown]
# #### 열 인덱싱(2): df[(상위인덱스, 하위인덱스)]
# - 인덱스가 하나가 아니므로 묶어서(튜플로) 전달해야 함
# - 시리즈로 반환

# %%
df[('A','C2')]
# Out:
# Series([], Name: (A, C2), dtype: object)

# %%
df['B','C3']
df[('B','C3')]
# Out:
# Series([], Name: (B, C3), dtype: object)
# Series([], Name: (B, C3), dtype: object)

# %% [markdown]
# #### 열인덱싱(3) :  . 연산자로 확장
#
# - df.상위인덱스
# - df.상위인덱스.하위인덱스

# %%
df.A
# Out:
# Empty DataFrame
# Columns: [C1, C2]
# Index: []

# %%
df.A.C1
# Out:
# Series([], Name: C1, dtype: object)

# %% [markdown]
# #### 열인덱스 이름 지정 : df.columns.names = []

# %%
df.columns.names = ['upper', 'lower']
df
# Out:
# Empty DataFrame
# Columns: [(A, C1), (A, C2), (B, C3), (B, C4)]
# Index: []

# %% [markdown]
# #### 2) 행인덱스를 다중 인덱스로 갖는 DataFrame

# %%
data2 = np.random.randint(1,10, size=(4,4))
data2
# Out:
# array([[9, 2, 7, 8],
#        [8, 9, 2, 6],
#        [9, 5, 4, 1],
#        [4, 6, 1, 3]])

# %%
df2 = pd.DataFrame(data=data2,
                  columns=['A','B','C','D'],
                  index = ['a a b b'.split(), '1 2 1 2'.split()])
df2
# Out:
#      A  B  C  D
# a 1  9  2  7  8
#   2  8  9  2  6
# b 1  9  5  4  1
#   2  4  6  1  3

# %%
df2.index
# Out:
# MultiIndex([('a', '1'),
#             ('a', '2'),
#             ('b', '1'),
#             ('b', '2')],
#            )

# %% [markdown]
# #### 행인덱싱(1) : df.loc[상위인덱스]

# %%
df2.loc['a']
# Out:
#    A  B  C  D
# 1  9  2  7  8
# 2  8  9  2  6

# %%
df2.loc[('a','1')]
# Out:
# A    9
# B    2
# C    7
# D    8
# Name: (a, 1), dtype: int64

# %%
df2.loc[['a','b']]
df2.loc['a':'b']
# Out:
#      A  B  C  D
# a 1  9  2  7  8
#   2  8  9  2  6
# b 1  9  5  4  1
#   2  4  6  1  3
#      A  B  C  D
# a 1  9  2  7  8
#   2  8  9  2  6
# b 1  9  5  4  1
#   2  4  6  1  3

# %% [markdown]
# #### 행인덱싱(2) : df.loc[(상위인덱스, 하위인덱스)]
# - 상위인덱스와 하위인덱스를 튜플로 전달

# %%
df2.loc[('a','1')]
df2.loc['a','1']
# Out:
# A    9
# B    2
# C    7
# D    8
# Name: (a, 1), dtype: int64
# A    9
# B    2
# C    7
# D    8
# Name: (a, 1), dtype: int64

# %% [markdown]
# #### 인덱서 iloc : df.iloc[  ]
# - iloc인덱서는 행이름, 열이름 기반이 아님

# %%
df2
df2.iloc[0]
# Out:
#      A  B  C  D
# a 1  9  2  7  8
#   2  8  9  2  6
# b 1  9  5  4  1
#   2  4  6  1  3
# A    9
# B    2
# C    7
# D    8
# Name: (a, 1), dtype: int64

# %%
df2.iloc[1,1:]
# Out:
# B    9
# C    2
# D    6
# Name: (a, 2), dtype: int64

# %%
df2.iloc[0,2]
# Out:
# 7

# %% [markdown]
# #### 3)  행과 열에 모두 다중인덱스를 갖는 DataFrame

# %%
np.random.seed(0)
data3 = np.round(np.random.randn(6,4),2)
data3
col1 = ['A']*2 + ['B']*2
col1
col2 = ['C'+str(i) for i in range(1,5)]
col2

columns = [col1, col2]
columns
idx1 = ['M']*3 + ['F']*3
idx2 = ['id_'+str(i) for i in range(1,4)]*2
index = [idx1, idx2]
index
# Out:
# array([[ 1.76,  0.4 ,  0.98,  2.24],
#        [ 1.87, -0.98,  0.95, -0.15],
#        [-0.1 ,  0.41,  0.14,  1.45],
#        [ 0.76,  0.12,  0.44,  0.33],
#        [ 1.49, -0.21,  0.31, -0.85],
#        [-2.55,  0.65,  0.86, -0.74]])
# ['A', 'A', 'B', 'B']
# ['C1', 'C2', 'C3', 'C4']
# [['A', 'A', 'B', 'B'], ['C1', 'C2', 'C3', 'C4']]
# [['M', 'M', 'M', 'F', 'F', 'F'],
#  ['id_1', 'id_2', 'id_3', 'id_1', 'id_2', 'id_3']]

# %%
df3 = pd.DataFrame(data=data3, index=index, columns=columns)
df3
# Out:
#            A           B
#           C1    C2    C3    C4
# M id_1  1.76  0.40  0.98  2.24
#   id_2  1.87 -0.98  0.95 -0.15
#   id_3 -0.10  0.41  0.14  1.45
# F id_1  0.76  0.12  0.44  0.33
#   id_2  1.49 -0.21  0.31 -0.85
#   id_3 -2.55  0.65  0.86 -0.74

# %% [markdown]
# #### 행/열 각 인덱스에 이름(names) 설정
#
# - 이름을 지정하면 직관성이 높아지고 편리하게 사용할 수 있음
# - 열이름/행이름 구분하는데 용이
# - 문법
#     - df.columns.names = 값 또는 리스트
#     - df.index.names = 값 또는 리스트

# %%
df3.index.names = ['Ridx1', 'Ridx2']
df3.columns.names = ['Cidx1', 'Cidx2']
df3
# Out:
# Cidx1           A           B
# Cidx2          C1    C2    C3    C4
# Ridx1 Ridx2
# M     id_1   1.76  0.40  0.98  2.24
#       id_2   1.87 -0.98  0.95 -0.15
#       id_3  -0.10  0.41  0.14  1.45
# F     id_1   0.76  0.12  0.44  0.33
#       id_2   1.49 -0.21  0.31 -0.85
#       id_3  -2.55  0.65  0.86 -0.74

# %%
df3['A']
# Out:
# Cidx2          C1    C2
# Ridx1 Ridx2
# M     id_1   1.76  0.40
#       id_2   1.87 -0.98
#       id_3  -0.10  0.41
# F     id_1   0.76  0.12
#       id_2   1.49 -0.21
#       id_3  -2.55  0.65

# %%
df3.loc['M', 'A']
# Out:
# Cidx2    C1    C2
# Ridx2
# id_1   1.76  0.40
# id_2   1.87 -0.98
# id_3  -0.10  0.41

# %%
df3.B
# Out:
# Cidx2          C3    C4
# Ridx1 Ridx2
# M     id_1   0.98  2.24
#       id_2   0.95 -0.15
#       id_3   0.14  1.45
# F     id_1   0.44  0.33
#       id_2   0.31 -0.85
#       id_3   0.86 -0.74

# %%
df3.B.loc['F']
# Out:
# Cidx2    C3    C4
# Ridx2
# id_1   0.44  0.33
# id_2   0.31 -0.85
# id_3   0.86 -0.74

# %%
df3.B.loc['F', 'id_1']
# Out:
# Cidx2
# C3    0.44
# C4    0.33
# Name: (F, id_1), dtype: float64

# %% [markdown]
# ### 3. MultiIndex 객체
# - https://pandas.pydata.org/docs/user_guide/advanced.html
#
# - 생성 방법
# 1. MultiIndex.from_arrays() 사용 : 배열(array)의 리스트
# 2. MultiIndex.from_tuples() : 튜플들(tuples)의 리스트
# 3. MultiIndex.from_product() : 리스트의 cross product
# 4. MultiIndex.from_frame() : DataFrame

# %%
# 1. MultiIndex.from_arrays() 이용한 다중인덱스 생성

arrays = np.array([['one', 'two', 'one', 'two'],
                   ['bar', 'baz', 'foo', 'quz']])

arrays
index = pd.MultiIndex.from_arrays(arrays, names=['first', 'second'])
index
# Out:
# array([['one', 'two', 'one', 'two'],
#        ['bar', 'baz', 'foo', 'quz']], dtype='<U3')
# MultiIndex([('one', 'bar'),
#             ('two', 'baz'),
#             ('one', 'foo'),
#             ('two', 'quz')],
#            names=['first', 'second'])

# %%
# 2. MultiIndex.from_tuples() 이용한 다중인덱스 생성

lists = [['one', 'two', 'one', 'two'],
        ['bar', 'baz', 'foo', 'quz']]
lists
tuples = list(zip(*lists))
tuples

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# [['one', 'two', 'one', 'two'], ['bar', 'baz', 'foo', 'quz']]
# [('one', 'bar'), ('two', 'baz'), ('one', 'foo'), ('two', 'quz')]
# MultiIndex([('one', 'bar'),
#             ('two', 'baz'),
#             ('one', 'foo'),
#             ('two', 'quz')],
#            names=['first', 'second'])

# %%
# 3. MultiIndex.from_product() 사용한 다중인덱스 생성

iterables = [['bar', 'baz', 'foo', 'quz'],
              ['one', 'two']]

index = pd.MultiIndex.from_product(iterables, names=['first','second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('quz', 'one'),
#             ('quz', 'two')],
#            names=['first', 'second'])

# %%
# 3. MultiIndex.from_product() 사용한 다중인덱스 생성

iterables = [['bar', 'baz', 'foo', 'quz'],
              ['one', 'two'],
                ['1', '2', '3']]

index = pd.MultiIndex.from_product(iterables, names=['first','second', 'third'])
index
# Out:
# MultiIndex([('bar', 'one', '1'),
#             ('bar', 'one', '2'),
#             ('bar', 'one', '3'),
#             ('bar', 'two', '1'),
#             ('bar', 'two', '2'),
#             ('bar', 'two', '3'),
#             ('baz', 'one', '1'),
#             ('baz', 'one', '2'),
#             ('baz', 'one', '3'),
#             ('baz', 'two', '1'),
#             ('baz', 'two', '2'),
#             ('baz', 'two', '3'),
#             ('foo', 'one', '1'),
#             ('foo', 'one', '2'),
#             ('foo', 'one', '3'),
#             ('foo', 'two', '1'),
#             ('foo', 'two', '2'),
#             ('foo', 'two', '3'),
#             ('quz', 'one', '1'),
#             ('quz', 'one', '2'),
#             ('quz', 'one', '3'),
#             ('quz', 'two', '1'),
#             ('quz', 'two', '2'),
#             ('quz', 'two', '3')],
#            names=['first', 'second', 'third'])

# %%
# 4. MultiIndex.from_frame()를 사용한 다중인덱스 생성

idx_df = pd.DataFrame([['bar', 'one'],['bar', 'two'],
                     ['baz', 'one'], ['baz', 'two']],
                     columns=['first', 'second'])
idx_df
index = pd.MultiIndex.from_frame(idx_df)
index
# Out:
#   first second
# 0   bar    one
# 1   bar    two
# 2   baz    one
# 3   baz    two
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two')],
#            names=['first', 'second'])

# %% [markdown]
# #### 예제. MultiIndex객체 생성하여 다중인덱스 설정

# %%
data4 = np.round(np.random.randn(4,9),1)
data4

index = pd.MultiIndex.from_product([[1995, 2000], ['May', 'Dec']], 
                                   names=['year', 'month'])
index

columns = pd.MultiIndex.from_product([['A','B','C'],[1,2,3]], 
                                     names=['name', 'count'])
columns

df4 = pd.DataFrame(data=data4, index=index, columns=columns)
df4
# Out:
# array([[ 2.3, -1.5,  0. , -0.2,  1.5,  1.5,  0.2,  0.4, -0.9],
#        [-2. , -0.3,  0.2,  1.2,  1.2, -0.4, -0.3, -1. , -1.4],
#        [-1.7,  2. , -0.5, -0.4, -1.3,  0.8, -1.6, -0.2, -0.9],
#        [ 0.4, -0.5, -1.2, -0. ,  0.4,  0.1,  0.3, -0.6, -0.4]])
# MultiIndex([(1995, 'May'),
#             (1995, 'Dec'),
#             (2000, 'May'),
#             (2000, 'Dec')],
#            names=['year', 'month'])
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('A', 3),
#             ('B', 1),
#             ('B', 2),
#             ('B', 3),
#             ('C', 1),
#             ('C', 2),
#             ('C', 3)],
#            names=['name', 'count'])
# name          A              B              C
# count         1    2    3    1    2    3    1    2    3
# year month
# 1995 May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
#      Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# 2000 May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
#      Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4

# %%
df4.A
# Out:
# count         1    2    3
# year month
# 1995 May    2.3 -1.5  0.0
#      Dec   -2.0 -0.3  0.2
# 2000 May   -1.7  2.0 -0.5
#      Dec    0.4 -0.5 -1.2

# %%
df4.index
df4.loc[1995]
# Out:
# MultiIndex([(1995, 'May'),
#             (1995, 'Dec'),
#             (2000, 'May'),
#             (2000, 'Dec')],
#            names=['year', 'month'])
# name     A              B              C
# count    1    2    3    1    2    3    1    2    3
# month
# May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
# Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4

# %%
df4.reset_index()
# Out:
# name   year month    A              B              C
# count                1    2    3    1    2    3    1    2    3
# 0      1995   May  2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
# 1      1995   Dec -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# 2      2000   May -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
# 3      2000   Dec  0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4

# %% [markdown]
# ### 4. 다중인덱스의 특정 레벨 제거 : droplevel(level, axis)

# %% [markdown]
# #### 1) 시리즈의 다중인덱스 레벨 제거

# %%
s2.droplevel(0)
s2
# Out:
#         score
# course
# Eng       100
# Math       90
# Eng        90
# Math       70
# Eng        85
# Math       90
#               score
# name  course
# James Eng       100
#       Math       90
# Ted   Eng        90
#       Math       70
# Adam  Eng        85
#       Math       90

# %% [markdown]
# #### 2) 데이터프레임에서 다중인덱스 레벨 제거

# %%
s2.droplevel(1)
# Out:
#        score
# name
# James    100
# James     90
# Ted       90
# Ted       70
# Adam      85
# Adam      90

# %% [markdown]
# #### 행인덱스 레벨 제거

# %%
df4.droplevel(level=0)
df4.droplevel(level=0, axis=0)
# Out:
# name     A              B              C
# count    1    2    3    1    2    3    1    2    3
# month
# May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
# Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
# Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4
# name     A              B              C
# count    1    2    3    1    2    3    1    2    3
# month
# May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
# Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
# Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4

# %% [markdown]
# #### 열인덱스 레벨 제거

# %%
df4
df4.droplevel(level=0, axis=1) #name A B C가 사라짐
# Out:
# name          A              B              C
# count         1    2    3    1    2    3    1    2    3
# year month
# 1995 May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
#      Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# 2000 May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
#      Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4
# count         1    2    3    1    2    3    1    2    3
# year month
# 1995 May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
#      Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# 2000 May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
#      Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4

# %%
df4.droplevel(level=1, axis=1)
# Out:
# name          A    A    A    B    B    B    C    C    C
# year month
# 1995 May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
#      Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# 2000 May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
#      Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4

# %% [markdown]
# ### 5. 행인덱스 레벨 해제 : unstack()
#
# : 행인덱스 -> 열인덱스로 변환

# %% [markdown]
# #### 1) 시리즈의 다중인덱스 레벨 해제
#
# - 해제된 레벨 인덱스는 열인덱스로 변경되며, 데이터프레임으로 반환됨

# %%
s1
# Out:
# bar  one    1.764052
#      two    0.400157
# baz  one    0.978738
#      two    2.240893
# foo  one    1.867558
#      two   -0.977278
# qux  one    0.950088
#      two   -0.151357
# dtype: float64

# %% [markdown]
# #### 마지막 레벨 해제 : unstack(level=-1)

# %%
s1
s1.unstack()
# Out:
# bar  one    1.764052
#      two    0.400157
# baz  one    0.978738
#      two    2.240893
# foo  one    1.867558
#      two   -0.977278
# qux  one    0.950088
#      two   -0.151357
# dtype: float64
#           one       two
# bar  1.764052  0.400157
# baz  0.978738  2.240893
# foo  1.867558 -0.977278
# qux  0.950088 -0.151357

# %% [markdown]
# #### 첫번째 레벨 해제 : unstack(level=0)

# %%
s1.unstack(level=0)
# Out:
#           bar       baz       foo       qux
# one  1.764052  0.978738  1.867558  0.950088
# two  0.400157  2.240893 -0.977278 -0.151357

# %% [markdown]
# #### 2) 데이터프레임의 다중 행인덱스 레벨 해제
#
# - 데이터프레임의 인덱스 레벨 해제
# - 해제된 레벨은 열인덱스 중 가장 마지막 레벨이 됨

# %% [markdown]
# [형식] DataFrame.unstack(level=-1, fill_value=None)
#
#
# - level : int, str, or list of these, default= -1 (last level)
#     - Level(s) of index to unstack, can pass level name.
#
# - fill_value : int, str or dict
#     - Replace NaN with this value if the unstack produces missing values.
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.unstack.html

# %%
df4
# Out:
# name          A              B              C
# count         1    2    3    1    2    3    1    2    3
# year month
# 1995 May    2.3 -1.5  0.0 -0.2  1.5  1.5  0.2  0.4 -0.9
#      Dec   -2.0 -0.3  0.2  1.2  1.2 -0.4 -0.3 -1.0 -1.4
# 2000 May   -1.7  2.0 -0.5 -0.4 -1.3  0.8 -1.6 -0.2 -0.9
#      Dec    0.4 -0.5 -1.2 -0.0  0.4  0.1  0.3 -0.6 -0.4

# %%
df4.unstack(level=0) #year이 컬럼으로 바뀜
# Out:
# name     A                             B                             C       \
# count    1         2         3         1         2         3         1
# year  1995 2000 1995 2000 1995 2000 1995 2000 1995 2000 1995 2000 1995 2000
# month
# Dec   -2.0  0.4 -0.3 -0.5  0.2 -1.2  1.2 -0.0  1.2  0.4 -0.4  0.1 -0.3  0.3
# May    2.3 -1.7 -1.5  2.0  0.0 -0.5 -0.2 -0.4  1.5 -1.3  1.5  0.8  0.2 -1.6
#
# name
# count    2         3
# year  1995 2000 1995 2000
# month
# Dec   -1.0 -0.6 -1.4 -0.4
# May    0.4 -0.2 -0.9 -0.9

# %%
df4.unstack(level='year') #year이 컬럼으로 바뀜
# Out:
# name     A                             B                             C       \
# count    1         2         3         1         2         3         1
# year  1995 2000 1995 2000 1995 2000 1995 2000 1995 2000 1995 2000 1995 2000
# month
# Dec   -2.0  0.4 -0.3 -0.5  0.2 -1.2  1.2 -0.0  1.2  0.4 -0.4  0.1 -0.3  0.3
# May    2.3 -1.7 -1.5  2.0  0.0 -0.5 -0.2 -0.4  1.5 -1.3  1.5  0.8  0.2 -1.6
#
# name
# count    2         3
# year  1995 2000 1995 2000
# month
# Dec   -1.0 -0.6 -1.4 -0.4
# May    0.4 -0.2 -0.9 -0.9

# %%
df4.unstack(level='month')
# Out:
# name     A                             B                             C       \
# count    1         2         3         1         2         3         1
# month  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May
# year
# 1995  -2.0  2.3 -0.3 -1.5  0.2  0.0  1.2 -0.2  1.2  1.5 -0.4  1.5 -0.3  0.2
# 2000   0.4 -1.7 -0.5  2.0 -1.2 -0.5 -0.0 -0.4  0.4 -1.3  0.1  0.8  0.3 -1.6
#
# name
# count    2         3
# month  Dec  May  Dec  May
# year
# 1995  -1.0  0.4 -1.4 -0.9
# 2000  -0.6 -0.2 -0.4 -0.9

# %%
df4.unstack()
# Out:
# name     A                             B                             C       \
# count    1         2         3         1         2         3         1
# month  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May
# year
# 1995  -2.0  2.3 -0.3 -1.5  0.2  0.0  1.2 -0.2  1.2  1.5 -0.4  1.5 -0.3  0.2
# 2000   0.4 -1.7 -0.5  2.0 -1.2 -0.5 -0.0 -0.4  0.4 -1.3  0.1  0.8  0.3 -1.6
#
# name
# count    2         3
# month  Dec  May  Dec  May
# year
# 1995  -1.0  0.4 -1.4 -0.9
# 2000  -0.6 -0.2 -0.4 -0.9

# %%
df4.unstack(1)
# Out:
# name     A                             B                             C       \
# count    1         2         3         1         2         3         1
# month  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May  Dec  May
# year
# 1995  -2.0  2.3 -0.3 -1.5  0.2  0.0  1.2 -0.2  1.2  1.5 -0.4  1.5 -0.3  0.2
# 2000   0.4 -1.7 -0.5  2.0 -1.2 -0.5 -0.0 -0.4  0.4 -1.3  0.1  0.8  0.3 -1.6
#
# name
# count    2         3
# month  Dec  May  Dec  May
# year
# 1995  -1.0  0.4 -1.4 -0.9
# 2000  -0.6 -0.2 -0.4 -0.9

# %% [markdown]
# ### 6. 열인덱스 레벨 해제 : stack()
#
# : 열인덱스 -> 행인덱스로 변환

# %% [markdown]
# #### 데이터프레임에서 열인덱스 레벨 해제

# %% [markdown]
# - 지정한 열인덱스가 행인덱스의 마지막 레벨로 변환 추가됨
# - single level 열인덱스를 갖는 경우 시리즈로 반환
# - multi level 열인덱스를 갖는 경우 데이터프레임 반환

# %% [markdown]
# [형식] DataFrame.stack(level=- 1, dropna=True)
#
# - level위치 또는 열이름 지정
# - level : int, str, list, default= -1
# - dropna : bool, default True
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html

# %% [markdown]
# #### 예1. 1차 레벨을 가진 데이터프레임

# %%
df5 = pd.DataFrame([[0,1],[2,3]], 
                  index=['cat','dog'],
                  columns=['weight', 'height'])
df5
# Out:
#      weight  height
# cat       0       1
# dog       2       3

# %%
df5.unstack()
# Out:
# weight  cat    0
#         dog    2
# height  cat    1
#         dog    3
# dtype: int64

# %%
df5.stack()
# Out:
# cat  weight    0
#      height    1
# dog  weight    2
#      height    3
# dtype: int64

# %%
df5.stack(level=0)
# Out:
# cat  weight    0
#      height    1
# dog  weight    2
#      height    3
# dtype: int64

# %% [markdown]
# #### 예2. 다중레벨을 갖는 데이터프레임

# %%
df
# Out:
# Empty DataFrame
# Columns: [(A, C1), (A, C2), (B, C3), (B, C4)]
# Index: []

# %%
df.stack()
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
df.stack(level=0)
# Out:
# Empty DataFrame
# Columns: [C1, C2, C3, C4]
# Index: []

# %%
df.stack(level=[0,1])
# Out:
# Series([], dtype: object)

# %% [markdown]
# #### 예3. 열인덱스 이름을 갖는 데이터프레임

# %%
df
# Out:
# Empty DataFrame
# Columns: [(A, C1), (A, C2), (B, C3), (B, C4)]
# Index: []

# %%
multicol2 = pd.MultiIndex.from_tuples([('weight','kg'),
                                      ('height', 'm')])

df6 = pd.DataFrame([[1.0,2.0],[3.0,4.0]],
                  index=['cat','dog'],
                  columns=multicol2)
df6
# Out:
#     weight height
#         kg      m
# cat    1.0    2.0
# dog    3.0    4.0

# %%
df6.stack()
# Out:
#         weight  height
# cat kg     1.0     NaN
#     m      NaN     2.0
# dog kg     3.0     NaN
#     m      NaN     4.0

# %% [markdown]
# ### 7. 다중인덱스의 레벨 교환 : swaplevel()

# %% [markdown]
# [형식] DataFrame.swaplevel(i=- 2, j=- 1, axis=0)
#
# - i, j : int or str
#     - Levels of the indices to be swapped. Can pass level name as string.
#
# - axis : 0 or ‘index’, 1 or ‘columns', default=0
#     - The axis to swap levels on
#     - 0 or‘index’ for row-wise
#     - 1 or ‘columns’ for column-wise
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.swaplevel.html

# %%
df = pd.DataFrame({"Grade": ["A", "B", "A", "C"]},
                  index=[
                      ["Final exam", "Final exam", "Coursework", "Coursework"],
                      ["History", "Geography", "History", "Geography"],
                      ["January", "February", "March", "April"],],)
df
# Out:
#                               Grade
# Final exam History   January      A
#            Geography February     B
# Coursework History   March        A
#            Geography April        C

# %%
df.swaplevel()
# Out:
#                               Grade
# Final exam January  History       A
#            February Geography     B
# Coursework March    History       A
#            April    Geography     C

# %%
df.swaplevel(0,1)
# Out:
#                               Grade
# History   Final exam January      A
# Geography Final exam February     B
# History   Coursework March        A
# Geography Coursework April        C

# %% [markdown]
# ### [정리] 다중인덱스의 접근 방법
#
# - 인덱스가 하나가 아니므로 묶어서(튜플로) 전달
# - 열 접근 : df[(튜플)]
# - 행 접근 : df.loc[(튜플)]
# - 참고. df.iloc[]은 정수위치로 접근하여 다중인덱스에 구애받지 않음

# %% [markdown]
# -----

# %% [markdown]
# ### 8. 다중인덱스의 행/열 추가

# %%
data = np.round(np.random.rand(6, 4), 2)
columns = pd.MultiIndex.from_product([['A','B'],['C1','C2']],
                                   names=['cidx1','cidx2'])
index = pd.MultiIndex.from_product([['M','F'],['id1','id2','id3']],
                                    names=['ridx1','ridx2'])
df = pd.DataFrame(data=data, index=index, columns=columns)
df
# Out:
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# M     id1    0.02  0.30  0.66  0.29
#       id2    0.62  0.43  0.14  0.30
#       id3    0.57  0.59  0.57  0.65
# F     id1    0.65  0.43  0.90  0.37
#       id2    0.44  0.89  0.81  0.70
#       id3    0.10  0.92  0.71  1.00

# %%
df.loc[('F','id1'),('B','C1')]= 100
df
# Out:
# cidx1           A             B
# cidx2          C1    C2      C1    C2
# ridx1 ridx2
# M     id1    0.74  0.96    0.25  0.58
#       id2    0.59  0.57    0.22  0.95
#       id3    0.45  0.85    0.70  0.30
# F     id1    0.81  0.40  100.00  0.58
#       id2    0.88  0.69    0.73  0.50
#       id3    0.96  0.64    0.42  0.61

# %% [markdown]
# #### 값입력을 위한 위치 지정 실수?

# %%
df.loc[('F','id1'),('B','C1')]= 100
df
# Out:
# cidx1           A             B
# cidx2          C1    C2      C1    C2
# ridx1 ridx2
# M     id1    0.74  0.96    0.25  0.58
#       id2    0.59  0.57    0.22  0.95
#       id3    0.45  0.85    0.70  0.30
# F     id1    0.81  0.40  100.00  0.58
#       id2    0.88  0.69    0.73  0.50
#       id3    0.96  0.64    0.42  0.61

# %%
df.drop(columns=[('B','C1')])
df
# Out:
# cidx1           A           B
# cidx2          C1    C2    C2
# ridx1 ridx2
# M     id1    0.74  0.96  0.58
#       id2    0.59  0.57  0.95
#       id3    0.45  0.85  0.30
# F     id1    0.81  0.40  0.58
#       id2    0.88  0.69  0.50
#       id3    0.96  0.64  0.61
# cidx1           A             B
# cidx2          C1    C2      C1    C2
# ridx1 ridx2
# M     id1    0.74  0.96    0.25  0.58
#       id2    0.59  0.57    0.22  0.95
#       id3    0.45  0.85    0.70  0.30
# F     id1    0.81  0.40  100.00  0.58
#       id2    0.88  0.69    0.73  0.50
#       id3    0.96  0.64    0.42  0.61

# %% [markdown]
# #### 각 행의 총합을 마지막 열로 추가

# %%
df[('Row', 'Sum')] = df2.sum(axis=1)
df
# Out:
# cidx1           A             B          Row
# cidx2          C1    C2      C1    C2    Sum
# ridx1 ridx2
# M     id1    0.74  0.96    0.25  0.58    NaN
#       id2    0.59  0.57    0.22  0.95    NaN
#       id3    0.45  0.85    0.70  0.30    NaN
# F     id1    0.81  0.40  100.00  0.58  200.0
#       id2    0.88  0.69    0.73  0.50    NaN
#       id3    0.96  0.64    0.42  0.61    NaN

# %% [markdown]
# #### 각 열의 총합을 마지막 행으로 추가

# %%
df.loc[('Col','Sum')] = df.sum(axis=0)
df
# Out:
# cidx1           A             B          Row Sum
# cidx2          C1    C2      C1    C2    Sum
# ridx1 ridx2
# M     id1    0.74  0.96    0.25  0.58    NaN NaN
#       id2    0.59  0.57    0.22  0.95    NaN NaN
#       id3    0.45  0.85    0.70  0.30    NaN NaN
# F     id1    0.81  0.40  100.00  0.58  200.0 NaN
#       id2    0.88  0.69    0.73  0.50    NaN NaN
#       id3    0.96  0.64    0.42  0.61    NaN NaN
# Col           NaN   NaN     NaN   NaN    NaN NaN

# %%
df.loc[('Col','Sum'),:] = df.sum(axis=0)
df
# Out:
# cidx1            A              B           Row  Sum
# cidx2           C1     C2      C1     C2    Sum
# ridx1 ridx2
# M     id1     0.74   0.96    0.25   0.58    NaN  NaN
#       id2     0.59   0.57    0.22   0.95    NaN  NaN
#       id3     0.45   0.85    0.70   0.30    NaN  NaN
# F     id1     0.81   0.40  100.00   0.58  200.0  NaN
#       id2     0.88   0.69    0.73   0.50    NaN  NaN
#       id3     0.96   0.64    0.42   0.61    NaN  NaN
# Col            NaN    NaN     NaN    NaN    NaN  NaN
#       Sum    13.29  12.33  306.96  10.56  600.0  0.0

# %% [markdown]
# ### 9. 다중인덱스 정렬
#
# ### 1) sort_index()
#
# [형식] sort_index(*, axis=0, level=None, ascending=True, inplace=False,)
#
# - 행/열 인덱스 기준으로 정렬
# - 기본 정렬 방식 : 오름차순 정렬
# - 내림차순 : ascending=Flase 설정

# %% [markdown]
# ####  행인덱스 정렬

# %%
df.sort_index()
df.sort_index(ascending=True)
# Out:
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# F     id1    0.65  0.43  0.90  0.37
#       id2    0.44  0.89  0.81  0.70
#       id3    0.10  0.92  0.71  1.00
# M     id1    0.02  0.30  0.66  0.29
#       id2    0.62  0.43  0.14  0.30
#       id3    0.57  0.59  0.57  0.65
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# F     id1    0.65  0.43  0.90  0.37
#       id2    0.44  0.89  0.81  0.70
#       id3    0.10  0.92  0.71  1.00
# M     id1    0.02  0.30  0.66  0.29
#       id2    0.62  0.43  0.14  0.30
#       id3    0.57  0.59  0.57  0.65

# %%
df.sort_index(level=1)
df.sort_index(level=1, ascending=True)
# Out:
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# F     id1    0.65  0.43  0.90  0.37
# M     id1    0.02  0.30  0.66  0.29
# F     id2    0.44  0.89  0.81  0.70
# M     id2    0.62  0.43  0.14  0.30
# F     id3    0.10  0.92  0.71  1.00
# M     id3    0.57  0.59  0.57  0.65
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# F     id1    0.65  0.43  0.90  0.37
# M     id1    0.02  0.30  0.66  0.29
# F     id2    0.44  0.89  0.81  0.70
# M     id2    0.62  0.43  0.14  0.30
# F     id3    0.10  0.92  0.71  1.00
# M     id3    0.57  0.59  0.57  0.65

# %% [markdown]
# #### 열인덱스 기준으로 정렬

# %%
df
df.sort_index(axis=1, ascending=False)
# Out:
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# M     id1    0.02  0.30  0.66  0.29
#       id2    0.62  0.43  0.14  0.30
#       id3    0.57  0.59  0.57  0.65
# F     id1    0.65  0.43  0.90  0.37
#       id2    0.44  0.89  0.81  0.70
#       id3    0.10  0.92  0.71  1.00
# cidx1           B           A
# cidx2          C2    C1    C2    C1
# ridx1 ridx2
# M     id1    0.29  0.66  0.30  0.02
#       id2    0.30  0.14  0.43  0.62
#       id3    0.65  0.57  0.59  0.57
# F     id1    0.37  0.90  0.43  0.65
#       id2    0.70  0.81  0.89  0.44
#       id3    1.00  0.71  0.92  0.10

# %%
df.sort_index(axis=1, level=1, ascending=False)
# Out:
# cidx1           B     A     B     A
# cidx2          C2    C2    C1    C1
# ridx1 ridx2
# M     id1    0.29  0.30  0.66  0.02
#       id2    0.30  0.43  0.14  0.62
#       id3    0.65  0.59  0.57  0.57
# F     id1    0.37  0.43  0.90  0.65
#       id2    0.70  0.89  0.81  0.44
#       id3    1.00  0.92  0.71  0.10

# %%
df.sort_index(axis=1, level=1)
# Out:
# cidx1           A     B     A     B
# cidx2          C1    C1    C2    C2
# ridx1 ridx2
# M     id1    0.02  0.66  0.30  0.29
#       id2    0.62  0.14  0.43  0.30
#       id3    0.57  0.57  0.59  0.65
# F     id1    0.65  0.90  0.43  0.37
#       id2    0.44  0.81  0.89  0.70
#       id3    0.10  0.71  0.92  1.00

# %% [markdown]
# ### 2) sort_values()
#
# [형식] ort_values(by, *, axis=0, ascending=True, inplace=False, )
#
# - 특정 컬럼 값을 기준으로 정렬
# - by = 특정컬럼
#     - 특정컬럼이 다중인덱스 일 경우 컬럼명을 튜플로 전달

# %% [markdown]
# #### df의 A.C1 컬럼을 기준으로 정렬

# %%
df.sort_values(by=('A','C1')) #A의 C1을 기준으로 오름차순 정렬
# Out:
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# M     id1    0.02  0.30  0.66  0.29
# F     id3    0.10  0.92  0.71  1.00
#       id2    0.44  0.89  0.81  0.70
# M     id3    0.57  0.59  0.57  0.65
#       id2    0.62  0.43  0.14  0.30
# F     id1    0.65  0.43  0.90  0.37

# %%
df.sort_values(by=[('A','C1'),('B','C2')]) #A의 C1, B의 C2 기준으로 오름차순 정렬
# Out:
# cidx1           A           B
# cidx2          C1    C2    C1    C2
# ridx1 ridx2
# M     id1    0.02  0.30  0.66  0.29
# F     id3    0.10  0.92  0.71  1.00
#       id2    0.44  0.89  0.81  0.70
# M     id3    0.57  0.59  0.57  0.65
#       id2    0.62  0.43  0.14  0.30
# F     id1    0.65  0.43  0.90  0.37

# %% [markdown]
# -----------
