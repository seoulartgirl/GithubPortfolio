# %% [markdown]
# 깃허브 연동 참고: https://velog.io/@shong676/Colab%EA%B3%BC-GitHub-%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0

# %% [markdown]
# ## add, 커밋, 푸쉬 방법

# %% [markdown]
# 1. 구글 드라이브 접근 - 코랩을 본인의 Google drive에 접근하게 하기 위한 코드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 2. Commit을 원하는 폴더로 이동

# %%
cd /content/drive/MyDrive/Colab Notebooks/GithubPortfolio
# Out:
# /content/drive/MyDrive/Colab Notebooks/GithubPortfolio

# %% [markdown]
# 3. 본인임을 확인

# %%
# !git config --global user.email 'seoulartgirl@gmail.com'
# !git config --global user.name 'seoulartgirl'

# %% [markdown]
# 4. 폴더 add
# - 원하는 폴더만 커밋 : !git add Test.ipynb
# - 폴더 내 모든 파일 커밋 : !git add --all

# %%
# !git add howtocommit.ipynb

# %%
# !git add --all

# %% [markdown]
# 5. commit 하기

# %%
# !git commit -m "crytsal's commit"
# !git push
# Out:
# [main 8e5bd8d] crytsal's commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite howtocommit.ipynb (61%)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 777 bytes | 55.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/seoulartgirl/GithubPortfolio.git
#    fe919e5..8e5bd8d  main -> main

# %% [markdown]
# ---

# %% [markdown]
# ## 초기 설정 방법

# %% [markdown]
# 1. 코랩을 본인의 Google drive에 접근하게 하기 위한 코드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. 본인이 연동시키고 싶은 폴더 명으로 이동

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# 3. Git clone 하기
# - username: 본인의 github 아이디
# - access token: 생성한 github 토큰
# - repository name: 생성한 github Repository 폴더 명.

# %%
# !git clone https://seoulartgirl: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@github.com/seoulartgirl/GithubPortfolio.git
# Out:
# Cloning into 'GithubPortfolio'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), done.

# %% [markdown]
# 4. 파일 확인
# - 이런식으로 나와야 함 '/content/drive/MyDrive/Commit_Test_Folder/Test_Repo'

# %%
cd GithubPortfolio
# Out:
# /content/drive/MyDrive/Colab Notebooks/GithubPortfolio

# %%
# !git config --global user.email 'seoulartgirl@gmail.com'
# !git config --global user.name 'seoulartgirl'
